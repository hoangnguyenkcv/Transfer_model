# %%
import keras
from keras.models import Sequential
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Flatten, Dropout, Activation, Lambda, Permute, Reshape, Merge
from keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D
from keras.optimizers import SGD, RMSprop, Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import  BatchNormalization
from keras.layers.convolutional import *
import numpy as np
import tensorflow as tf
# import theano
import  matplotlib.pyplot as plt
from PIL import Image
import matplotlib
import itertools
from numpy import*
from sklearn.utils import shuffle
# %matplotlib inline
import random as rn
import os
import math
import copy
os.environ['PYTHONASHSEED']= '0'
# Out:
# Using TensorFlow backend.

# %%
import os
classes_name = []
files_name = []
for root, dirs, files in os.walk('Dataset1/train_data'):  
    for name in dirs:
        classes_name.append(name)
    for name1 in files:
        files_name.append(name1)

print(len(classes_name))
print(len(files_name))
# Out:
# 2
# 321

# %%
# ########### Define  function to split  dataset #######################

# import shutil, sys  
# def split_dataset_into_test_and_train_sets(all_data_dir, training_data_dir, testing_data_dir, testing_data_pct):
    
#     if not os.path.exists(training_data_dir):
#         os.makedirs(training_data_dir)
#     if not os.path.exists(testing_data_dir):
#         os.makedirs(testing_data_dir)
#     # Recreate testing and training directories
#     if testing_data_dir.count('/') > 1:
#         shutil.rmtree(testing_data_dir, ignore_errors=False)
#         os.makedirs(testing_data_dir)
#         print("Successfully cleaned directory " + testing_data_dir)
#     else:
#         print("Refusing to delete testing data directory " + testing_data_dir + " as we prevent you from doing stupid things!")

#     if training_data_dir.count('/') > 1:
#         shutil.rmtree(training_data_dir, ignore_errors=False)
#         os.makedirs(training_data_dir)
#         print("Successfully cleaned directory " + training_data_dir)
#     else:
#         print("Refusing to delete testing data directory " + training_data_dir + " as we prevent you from doing stupid things!")

#     num_training_files = 0
#     num_testing_files = 0

#     for subdir, dirs, files in os.walk(all_data_dir):
#         category_name = os.path.basename(subdir)                        ### find  name  of classes

#         # Don't create a subdirectory for the root directory
#         print(category_name + " vs " + os.path.basename(all_data_dir))
#         if category_name == os.path.basename(all_data_dir):
#             continue

#         training_data_category_dir = training_data_dir + '/' + category_name
#         testing_data_category_dir = testing_data_dir + '/' + category_name

#         if not os.path.exists(training_data_category_dir):
#             os.mkdir(training_data_category_dir)

#         if not os.path.exists(testing_data_category_dir):
#             os.mkdir(testing_data_category_dir)

#         for file in files:
#             input_file = os.path.join(subdir, file)
#             if np.random.rand(1) < testing_data_pct:
#                 shutil.copy(input_file, testing_data_dir + '/' + category_name + '/' + file)
#                 num_testing_files += 1
#             else:
#                 shutil.copy(input_file, training_data_dir + '/' + category_name + '/' + file)
#                 num_training_files += 1

#     print("Processed " + str(num_training_files) + " training files.")
#     print("Processed " + str(num_testing_files) + " testing files.")

# %%
##### Split data into train_data and test data
# split_dataset_into_test_and_train_sets('Data2','Dataset2/train_data', 'Dataset2/test_data', 0.2)

# %%
##### calculate  number of images
import os
classes_name_train = []
files_name_train = []
classes_name_test = []
files_name_test = []
for root, dirs, files in os.walk('Dataset1/train_data'):  
    for name in dirs:
        classes_name_train.append(name)
    for name1 in files:
        files_name_train.append(name1)
        
for root, dirs, files in os.walk('Dataset1/test_data'):  
    for name in dirs:
        classes_name_test.append(name)
    for name1 in files:
        files_name_test.append(name1)

no_training = len(files_name_train)
no_testing = len(files_name_test)
        
print(len(classes_name_train))
print(len(files_name_train))
print(len(classes_name_test))
print(len(files_name_test))
number_classes = len(classes_name_train)
# Out:
# 2
# 321
# 2
# 79

# %%
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=True,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
# Out:
# C:\Users\hoanganh\Anaconda3\lib\site-packages\keras\preprocessing\image.py:526: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
#### set parameters
batch_size = 8
n_epochs= 500

# %%
train_path = 'Dataset1/train_data'
test_path = 'Dataset1/test_data'
train_batches = data_generator.flow_from_directory(train_path, target_size = (224,224), classes = classes_name, batch_size = batch_size)
test_batches = data_generator.flow_from_directory(test_path, target_size = (224,224), classes = classes_name, batch_size = batch_size)
# Out:
# Found 321 images belonging to 2 classes.
# Found 79 images belonging to 2 classes.

# %%
# plots images with labels  within jupyter notebook

def plots(ims, figsize = (12,6), rows=1, interp =False , titles = None):
    if  type(ims[0]) is  np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] !=3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize = figsize) 
    cols = len(ims)// rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows,cols,i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation = None if interp else 'none')
        plt.show()

# %%
imgs, labels = next(train_batches)
plots(imgs, titles = labels)
# Out:
# C:\Users\hoanganh\Anaconda3\lib\site-packages\keras\preprocessing\image.py:594: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# C:\Users\hoanganh\Anaconda3\lib\site-packages\keras\preprocessing\image.py:602: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
######### fine_tune vgg_face 
def convblock(cdim, nb, bits=3):
    L = []
    
    for k in range(1,bits+1):
        convname = 'conv'+str(nb)+'_'+str(k)
        #L.append( Convolution2D(cdim, 3, 3, border_mode='same', activation='relu', name=convname) ) # Keras 1
        L.append( Convolution2D(cdim, kernel_size=(3, 3), padding='same', activation='relu', name=convname) ) # Keras 2
    
    L.append( MaxPooling2D((2, 2), strides=(2, 2)) )
    
    return L

# %%
def vgg_face_blank():
    
    withDO = True # no effect during evaluation but usefull for fine-tuning
    
    if True:
        mdl = Sequential()
        
        # First layer is a dummy-permutation = Identity to specify input shape
        mdl.add( Permute((1,2,3), input_shape=(224,224,3)) ) # WARNING : 0 is the sample dim

        for l in convblock(64, 1, bits=2):
            mdl.add(l)

        for l in convblock(128, 2, bits=2):
            mdl.add(l)
        
        for l in convblock(256, 3, bits=3):
            mdl.add(l)
            
        for l in convblock(512, 4, bits=3):
            mdl.add(l)
            
        for l in convblock(512, 5, bits=3):
            mdl.add(l)
        
        #mdl.add( Convolution2D(4096, 7, 7, activation='relu', name='fc6') ) # Keras 1
        mdl.add( Convolution2D(4096, kernel_size=(7, 7), activation='relu', name='fc6') ) # Keras 2
        if withDO:
            mdl.add( Dropout(0.5) )
        #mdl.add( Convolution2D(4096, 1, 1, activation='relu', name='fc7') ) # Keras 1
        mdl.add( Convolution2D(4096, kernel_size=(1, 1), activation='relu', name='fc7') ) # Keras 2
        if withDO:
            mdl.add( Dropout(0.5) )
        #mdl.add( Convolution2D(2622, 1, 1, name='fc8') ) # Keras 1
        mdl.add( Convolution2D(2622, kernel_size=(1, 1), activation='relu', name='fc8') ) # Keras 2
        mdl.add( Flatten() )
        mdl.add( Activation('softmax') )
        
        return mdl
    
    else:
        # See following link for a version based on Keras functional API :
        # gist.github.com/EncodeTS/6bbe8cb8bebad7a672f0d872561782d9
        raise ValueError('not implemented')

# %%
facemodel = vgg_face_blank()

# %%
facemodel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# fc6 (Conv2D)                 (None, 1, 1, 4096)        102764544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# fc7 (Conv2D)                 (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# fc8 (Conv2D)                 (None, 1, 1, 2622)        10742334
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2622)              0
# _________________________________________________________________
# activation_1 (Activation)    (None, 2622)              0
# =================================================================
# Total params: 145,002,878
# Trainable params: 145,002,878
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
for layer in facemodel.layers:
    model.add(layer)

# %%
from scipy.io import loadmat
data = loadmat('vgg-face.mat', matlab_compatible=False, struct_as_record=False)
l = data['layers']
description = data['meta'][0,0].classes[0,0].description

# %%
def weight_compare(kmodel):
    kerasnames = [lr.name for lr in kmodel.layers]

    # WARNING : important setting as 2 of the 4 axis have same size dimension
    #prmt = (3,2,0,1) # INFO : for 'th' setting of 'dim_ordering'
    prmt = (0,1,2,3) # INFO : for 'channels_last' setting of 'image_data_format'

    for i in range(l.shape[1]):
        matname = l[0,i][0,0].name[0]
        mattype = l[0,i][0,0].type[0]
        if matname in kerasnames:
            kindex = kerasnames.index(matname)
            print(matname, mattype)
            print(l[0,i][0,0].weights[0,0].transpose(prmt).shape, l[0,i][0,0].weights[0,1].shape)
            print(kmodel.layers[kindex].get_weights()[0].shape, kmodel.layers[kindex].get_weights()[1].shape)
            print('------------------------------------------')
        else:
            print('MISSING : ', matname, mattype)
            print('------------------------------------------')

# %%
def copy_mat_to_keras(kmodel):

    kerasnames = [lr.name for lr in kmodel.layers]

    # WARNING : important setting as 2 of the 4 axis have same size dimension
    #prmt = (3,2,0,1) # INFO : for 'th' setting of 'dim_ordering'
    prmt = (0,1,2,3) # INFO : for 'channels_last' setting of 'image_data_format'

    for i in range(l.shape[1]):
        matname = l[0,i][0,0].name[0]
        if matname in kerasnames:
            kindex = kerasnames.index(matname)
            #print matname
            l_weights = l[0,i][0,0].weights[0,0]
            l_bias = l[0,i][0,0].weights[0,1]
            f_l_weights = l_weights.transpose(prmt)
            #f_l_weights = np.flip(f_l_weights, 2) # INFO : for 'th' setting in dim_ordering
            #f_l_weights = np.flip(f_l_weights, 3) # INFO : for 'th' setting in dim_ordering
            assert (f_l_weights.shape == kmodel.layers[kindex].get_weights()[0].shape)
            assert (l_bias.shape[1] == 1)
            assert (l_bias[:,0].shape == kmodel.layers[kindex].get_weights()[1].shape)
            assert (len(kmodel.layers[kindex].get_weights()) == 2)
            kmodel.layers[kindex].set_weights([f_l_weights, l_bias[:,0]])
            #print '------------------------------------------'

# %%
copy_mat_to_keras(model)

# %%
## remove  last layer  of  vgg_face 
model.layers.pop() 
# model.summary()

# %%
### add SVM in the  last layer
from keras import regularizers
model.add(Dense(2, activation = 'linear', kernel_regularizer=regularizers.l2(0.001)))

#### set trainable layer  
#for layer in model.layers:
#    layer.trainable = True

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# fc6 (Conv2D)                 (None, 1, 1, 4096)        102764544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# fc7 (Conv2D)                 (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# fc8 (Conv2D)                 (None, 1, 1, 2622)        10742334
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2622)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 5246
# =================================================================
# Total params: 145,008,124
# Trainable params: 145,008,124
# Non-trainable params: 0
# _________________________________________________________________

# %%
n = len(model.layers)
for idx, layer in enumerate(model.layers):
    if idx < (n-2): 
           layer.trainable = False
    else:
           layer.trainable = True

# %%
##### compile with SGD
# sgd = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(loss='hinge', optimizer=sgd, metrics=['accuracy'])

#### compile with Adam 
opt = Adam(lr=0.001, decay=10e-6)
model.compile(loss='hinge', optimizer=opt, metrics=['accuracy'])

#model.compile(loss='hinge', optimizer='adadelta', metrics=['accuracy'])

# %%
### training    
from keras.callbacks import ModelCheckpoint
# Save check point
filepath = "vggface2.weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose =1, save_best_only = True, mode ='max')
callbacks_list= [checkpoint]
 # Fit the model
# model.fit(X,Y, validation_split=0.33, nb_epoch =150, batch_size =10, callbacks = callbacks_list, verbose =0)

history = model.fit_generator(train_batches, steps_per_epoch = int(no_training / batch_size), validation_data = test_batches, validation_steps = int(no_testing / batch_size), epochs = n_epochs, shuffle=True, callbacks = callbacks_list, verbose =2)
# Out:
# Epoch 1/500
# C:\Users\hoanganh\Anaconda3\lib\site-packages\keras\preprocessing\image.py:594: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# C:\Users\hoanganh\Anaconda3\lib\site-packages\keras\preprocessing\image.py:602: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
#  - 5s - loss: 0.9904 - acc: 0.4940 - val_loss: 0.9781 - val_acc: 0.5278
#
# Epoch 00001: val_acc improved from -inf to 0.52778, saving model to vggface2.weights.best.hdf5
# Epoch 2/500
#  - 5s - loss: 0.9665 - acc: 0.5284 - val_loss: 0.9569 - val_acc: 0.6111
#
# Epoch 00002: val_acc improved from 0.52778 to 0.61111, saving model to vggface2.weights.best.hdf5
# Epoch 3/500
#  - 4s - loss: 0.9451 - acc: 0.6310 - val_loss: 0.9361 - val_acc: 0.6667
#
# Epoch 00003: val_acc improved from 0.61111 to 0.66667, saving model to vggface2.weights.best.hdf5
# Epoch 4/500
#  - 5s - loss: 0.9244 - acc: 0.6691 - val_loss: 0.9169 - val_acc: 0.5417
#
# Epoch 00004: val_acc did not improve
# Epoch 5/500
#  - 4s - loss: 0.9034 - acc: 0.6941 - val_loss: 0.8962 - val_acc: 0.6806
#
# Epoch 00005: val_acc improved from 0.66667 to 0.68056, saving model to vggface2.weights.best.hdf5
# Epoch 6/500
#  - 5s - loss: 0.8832 - acc: 0.6875 - val_loss: 0.8767 - val_acc: 0.6944
#
# Epoch 00006: val_acc improved from 0.68056 to 0.69444, saving model to vggface2.weights.best.hdf5
# Epoch 7/500
#  - 4s - loss: 0.8626 - acc: 0.7435 - val_loss: 0.8571 - val_acc: 0.6528
#
# Epoch 00007: val_acc did not improve
# Epoch 8/500
#  - 4s - loss: 0.8422 - acc: 0.7592 - val_loss: 0.8374 - val_acc: 0.6528
#
# Epoch 00008: val_acc did not improve
# Epoch 9/500
#  - 4s - loss: 0.8219 - acc: 0.7281 - val_loss: 0.8178 - val_acc: 0.7083
#
# Epoch 00009: val_acc improved from 0.69444 to 0.70833, saving model to vggface2.weights.best.hdf5
# Epoch 10/500
#  - 4s - loss: 0.8015 - acc: 0.7561 - val_loss: 0.7983 - val_acc: 0.6944
#
# Epoch 00010: val_acc did not improve
# Epoch 11/500
#  - 4s - loss: 0.7825 - acc: 0.7405 - val_loss: 0.7797 - val_acc: 0.7361
#
# Epoch 00011: val_acc improved from 0.70833 to 0.73611, saving model to vggface2.weights.best.hdf5
# Epoch 12/500
#  - 4s - loss: 0.7633 - acc: 0.7560 - val_loss: 0.7616 - val_acc: 0.6667
#
# Epoch 00012: val_acc did not improve
# Epoch 13/500
#  - 4s - loss: 0.7421 - acc: 0.7655 - val_loss: 0.7402 - val_acc: 0.7500
#
# Epoch 00013: val_acc improved from 0.73611 to 0.75000, saving model to vggface2.weights.best.hdf5
# Epoch 14/500
#  - 4s - loss: 0.7225 - acc: 0.8061 - val_loss: 0.7210 - val_acc: 0.7778
#
# Epoch 00014: val_acc improved from 0.75000 to 0.77778, saving model to vggface2.weights.best.hdf5
# Epoch 15/500
#  - 4s - loss: 0.7034 - acc: 0.7874 - val_loss: 0.7034 - val_acc: 0.6528
#
# Epoch 00015: val_acc did not improve
# Epoch 16/500
#  - 4s - loss: 0.6836 - acc: 0.7688 - val_loss: 0.6827 - val_acc: 0.6389
#
# Epoch 00016: val_acc did not improve
# Epoch 17/500
#  - 4s - loss: 0.6627 - acc: 0.7410 - val_loss: 0.6634 - val_acc: 0.6250
#
# Epoch 00017: val_acc did not improve
# Epoch 18/500
#  - 4s - loss: 0.6446 - acc: 0.6903 - val_loss: 0.6446 - val_acc: 0.7083
#
# Epoch 00018: val_acc did not improve
# Epoch 19/500
#  - 4s - loss: 0.6241 - acc: 0.7936 - val_loss: 0.6262 - val_acc: 0.6944
#
# Epoch 00019: val_acc did not improve
# Epoch 20/500
#  - 4s - loss: 0.6051 - acc: 0.7874 - val_loss: 0.6082 - val_acc: 0.6389
#
# Epoch 00020: val_acc did not improve
# Epoch 21/500
#  - 4s - loss: 0.5868 - acc: 0.7191 - val_loss: 0.5908 - val_acc: 0.6944
#
# Epoch 00021: val_acc did not improve
# Epoch 22/500
#  - 4s - loss: 0.5663 - acc: 0.8094 - val_loss: 0.5697 - val_acc: 0.6944
#
# Epoch 00022: val_acc did not improve
# Epoch 23/500
#  - 4s - loss: 0.5487 - acc: 0.7966 - val_loss: 0.5539 - val_acc: 0.6806
#
# Epoch 00023: val_acc did not improve
# Epoch 24/500
#  - 4s - loss: 0.5309 - acc: 0.8219 - val_loss: 0.5362 - val_acc: 0.6806
#
# Epoch 00024: val_acc did not improve
# Epoch 25/500
#  - 4s - loss: 0.5192 - acc: 0.8405 - val_loss: 0.5249 - val_acc: 0.7083
#
# Epoch 00025: val_acc did not improve
# Epoch 26/500
#  - 4s - loss: 0.5143 - acc: 0.8187 - val_loss: 0.5207 - val_acc: 0.7222
#
# Epoch 00026: val_acc did not improve
# Epoch 27/500
#  - 4s - loss: 0.5116 - acc: 0.8593 - val_loss: 0.5177 - val_acc: 0.6944
#
# Epoch 00027: val_acc did not improve
# Epoch 28/500
#  - 4s - loss: 0.5105 - acc: 0.8218 - val_loss: 0.5154 - val_acc: 0.7222
#
# Epoch 00028: val_acc did not improve
# Epoch 29/500
#  - 4s - loss: 0.5096 - acc: 0.8280 - val_loss: 0.5135 - val_acc: 0.6944
#
# Epoch 00029: val_acc did not improve
# Epoch 30/500
#  - 4s - loss: 0.5086 - acc: 0.8280 - val_loss: 0.5128 - val_acc: 0.7083
#
# Epoch 00030: val_acc did not improve
# Epoch 31/500
#  - 4s - loss: 0.5082 - acc: 0.8405 - val_loss: 0.5119 - val_acc: 0.6806
#
# Epoch 00031: val_acc did not improve
# Epoch 32/500
#  - 4s - loss: 0.5076 - acc: 0.8312 - val_loss: 0.5108 - val_acc: 0.7083
#
# Epoch 00032: val_acc did not improve
# Epoch 33/500
#  - 4s - loss: 0.5068 - acc: 0.8437 - val_loss: 0.5095 - val_acc: 0.7361
#
# Epoch 00033: val_acc did not improve
# Epoch 34/500
#  - 4s - loss: 0.5065 - acc: 0.8343 - val_loss: 0.5087 - val_acc: 0.7361
#
# Epoch 00034: val_acc did not improve
# Epoch 35/500
#  - 4s - loss: 0.5059 - acc: 0.7723 - val_loss: 0.5079 - val_acc: 0.7083
#
# Epoch 00035: val_acc did not improve
# Epoch 36/500
#  - 4s - loss: 0.5055 - acc: 0.8192 - val_loss: 0.5071 - val_acc: 0.6806
#
# Epoch 00036: val_acc did not improve
# Epoch 37/500
#  - 4s - loss: 0.5052 - acc: 0.8437 - val_loss: 0.5065 - val_acc: 0.7778
#
# Epoch 00037: val_acc did not improve
# Epoch 38/500
#  - 4s - loss: 0.5048 - acc: 0.8066 - val_loss: 0.5062 - val_acc: 0.6528
#
# Epoch 00038: val_acc did not improve
# Epoch 39/500
#  - 4s - loss: 0.5044 - acc: 0.8250 - val_loss: 0.5057 - val_acc: 0.6944
#
# Epoch 00039: val_acc did not improve
# Epoch 40/500
#  - 4s - loss: 0.5041 - acc: 0.8192 - val_loss: 0.5052 - val_acc: 0.6250
#
# Epoch 00040: val_acc did not improve
# Epoch 41/500
#  - 4s - loss: 0.5038 - acc: 0.8468 - val_loss: 0.5049 - val_acc: 0.6667
#
# Epoch 00041: val_acc did not improve
# Epoch 42/500
#  - 4s - loss: 0.5036 - acc: 0.8312 - val_loss: 0.5044 - val_acc: 0.7083
#
# Epoch 00042: val_acc did not improve
# Epoch 43/500
#  - 4s - loss: 0.5033 - acc: 0.7999 - val_loss: 0.5043 - val_acc: 0.6667
#
# Epoch 00043: val_acc did not improve
# Epoch 44/500
#  - 4s - loss: 0.5031 - acc: 0.7999 - val_loss: 0.5037 - val_acc: 0.7500
#
# Epoch 00044: val_acc did not improve
# Epoch 45/500
#  - 4s - loss: 0.5028 - acc: 0.8187 - val_loss: 0.5034 - val_acc: 0.6806
#
# Epoch 00045: val_acc did not improve
# Epoch 46/500
#  - 4s - loss: 0.5026 - acc: 0.8312 - val_loss: 0.5033 - val_acc: 0.6944
#
# Epoch 00046: val_acc did not improve
# Epoch 47/500
#  - 4s - loss: 0.5025 - acc: 0.7911 - val_loss: 0.5030 - val_acc: 0.6528
#
# Epoch 00047: val_acc did not improve
# Epoch 48/500
#  - 4s - loss: 0.5023 - acc: 0.8281 - val_loss: 0.5026 - val_acc: 0.6667
#
# Epoch 00048: val_acc did not improve
# Epoch 49/500
#  - 4s - loss: 0.5021 - acc: 0.8066 - val_loss: 0.5023 - val_acc: 0.6944
#
# Epoch 00049: val_acc did not improve
# Epoch 50/500
#  - 4s - loss: 0.5020 - acc: 0.7973 - val_loss: 0.5022 - val_acc: 0.6250
#
# Epoch 00050: val_acc did not improve
# Epoch 51/500
#  - 4s - loss: 0.5018 - acc: 0.8281 - val_loss: 0.5020 - val_acc: 0.7083
#
# Epoch 00051: val_acc did not improve
# Epoch 52/500
#  - 4s - loss: 0.5017 - acc: 0.7696 - val_loss: 0.5019 - val_acc: 0.6667
#
# Epoch 00052: val_acc did not improve
# Epoch 53/500
#  - 4s - loss: 0.5016 - acc: 0.8124 - val_loss: 0.5017 - val_acc: 0.6667
#
# Epoch 00053: val_acc did not improve
# Epoch 54/500
#  - 4s - loss: 0.5014 - acc: 0.7875 - val_loss: 0.5015 - val_acc: 0.6528
#
# Epoch 00054: val_acc did not improve
# Epoch 55/500
#  - 4s - loss: 0.5013 - acc: 0.8035 - val_loss: 0.5014 - val_acc: 0.6389
#
# Epoch 00055: val_acc did not improve
# Epoch 56/500
#  - 4s - loss: 0.5012 - acc: 0.7718 - val_loss: 0.5014 - val_acc: 0.6806
#
# Epoch 00056: val_acc did not improve
# Epoch 57/500
#  - 4s - loss: 0.5012 - acc: 0.7874 - val_loss: 0.5012 - val_acc: 0.6806
#
# Epoch 00057: val_acc did not improve
# Epoch 58/500
#  - 4s - loss: 0.5011 - acc: 0.8156 - val_loss: 0.5011 - val_acc: 0.7083
#
# Epoch 00058: val_acc did not improve
# Epoch 59/500
#  - 4s - loss: 0.5010 - acc: 0.8248 - val_loss: 0.5010 - val_acc: 0.5972
#
# Epoch 00059: val_acc did not improve
# Epoch 60/500
#  - 4s - loss: 0.5009 - acc: 0.7625 - val_loss: 0.5009 - val_acc: 0.5972
#
# Epoch 00060: val_acc did not improve
# Epoch 61/500
#  - 4s - loss: 0.5008 - acc: 0.8279 - val_loss: 0.5009 - val_acc: 0.6806
#
# Epoch 00061: val_acc did not improve
# Epoch 62/500
#  - 3s - loss: 0.5008 - acc: 0.7692 - val_loss: 0.5008 - val_acc: 0.6528
#
# Epoch 00062: val_acc did not improve
# Epoch 63/500
#  - 3s - loss: 0.5007 - acc: 0.7780 - val_loss: 0.5007 - val_acc: 0.6806
#
# Epoch 00063: val_acc did not improve
# Epoch 64/500
#  - 4s - loss: 0.5007 - acc: 0.7938 - val_loss: 0.5007 - val_acc: 0.6111
#
# Epoch 00064: val_acc did not improve
# Epoch 65/500
#  - 4s - loss: 0.5006 - acc: 0.8312 - val_loss: 0.5006 - val_acc: 0.5417
#
# Epoch 00065: val_acc did not improve
# Epoch 66/500
#  - 4s - loss: 0.5006 - acc: 0.7843 - val_loss: 0.5006 - val_acc: 0.5833
#
# Epoch 00066: val_acc did not improve
# Epoch 67/500
#  - 4s - loss: 0.5005 - acc: 0.7811 - val_loss: 0.5005 - val_acc: 0.5833
#
# Epoch 00067: val_acc did not improve
# Epoch 68/500
#  - 3s - loss: 0.5005 - acc: 0.7685 - val_loss: 0.5005 - val_acc: 0.6667
#
# Epoch 00068: val_acc did not improve
# Epoch 69/500
#  - 4s - loss: 0.5004 - acc: 0.7848 - val_loss: 0.5004 - val_acc: 0.6667
#
# Epoch 00069: val_acc did not improve
# Epoch 70/500
#  - 4s - loss: 0.5004 - acc: 0.7812 - val_loss: 0.5004 - val_acc: 0.6667
#
# Epoch 00070: val_acc did not improve
# Epoch 71/500
#  - 3s - loss: 0.5004 - acc: 0.7915 - val_loss: 0.5004 - val_acc: 0.6944
#
# Epoch 00071: val_acc did not improve
# Epoch 72/500
#  - 4s - loss: 0.5003 - acc: 0.8031 - val_loss: 0.5003 - val_acc: 0.6528
#
# Epoch 00072: val_acc did not improve
# Epoch 73/500
#  - 4s - loss: 0.5003 - acc: 0.7785 - val_loss: 0.5003 - val_acc: 0.6389
#
# Epoch 00073: val_acc did not improve
# Epoch 74/500
#  - 4s - loss: 0.5003 - acc: 0.7843 - val_loss: 0.5003 - val_acc: 0.6944
#
# Epoch 00074: val_acc did not improve
# Epoch 75/500
#  - 4s - loss: 0.5003 - acc: 0.7747 - val_loss: 0.5003 - val_acc: 0.6528
#
# Epoch 00075: val_acc did not improve
# Epoch 76/500
#  - 4s - loss: 0.5003 - acc: 0.7316 - val_loss: 0.5002 - val_acc: 0.5556
#
# Epoch 00076: val_acc did not improve
# Epoch 77/500
#  - 4s - loss: 0.5002 - acc: 0.7750 - val_loss: 0.5002 - val_acc: 0.6111
#
# Epoch 00077: val_acc did not improve
# Epoch 78/500
#  - 4s - loss: 0.5002 - acc: 0.7753 - val_loss: 0.5002 - val_acc: 0.6111
#
# Epoch 00078: val_acc did not improve
# Epoch 79/500
#  - 4s - loss: 0.5002 - acc: 0.7625 - val_loss: 0.5002 - val_acc: 0.6111
#
# Epoch 00079: val_acc did not improve
# Epoch 80/500
#  - 4s - loss: 0.5002 - acc: 0.7467 - val_loss: 0.5002 - val_acc: 0.5972
#
# Epoch 00080: val_acc did not improve
# Epoch 81/500
#  - 4s - loss: 0.5002 - acc: 0.7467 - val_loss: 0.5002 - val_acc: 0.5556
#
# Epoch 00081: val_acc did not improve
# Epoch 82/500
#  - 3s - loss: 0.5002 - acc: 0.7499 - val_loss: 0.5001 - val_acc: 0.6111
#
# Epoch 00082: val_acc did not improve
# Epoch 83/500
#  - 4s - loss: 0.5001 - acc: 0.7843 - val_loss: 0.5001 - val_acc: 0.6250
#
# Epoch 00083: val_acc did not improve
# Epoch 84/500
#  - 4s - loss: 0.5001 - acc: 0.7342 - val_loss: 0.5001 - val_acc: 0.5417
#
# Epoch 00084: val_acc did not improve
# Epoch 85/500
#  - 4s - loss: 0.5001 - acc: 0.7561 - val_loss: 0.5001 - val_acc: 0.5833
#
# Epoch 00085: val_acc did not improve
# Epoch 86/500
#  - 4s - loss: 0.5001 - acc: 0.7123 - val_loss: 0.5001 - val_acc: 0.5972
#
# Epoch 00086: val_acc did not improve
# Epoch 87/500
#  - 4s - loss: 0.5001 - acc: 0.7092 - val_loss: 0.5001 - val_acc: 0.5694
#
# Epoch 00087: val_acc did not improve
# Epoch 88/500
#  - 4s - loss: 0.5001 - acc: 0.7098 - val_loss: 0.5001 - val_acc: 0.5417
#
# Epoch 00088: val_acc did not improve
# Epoch 89/500
#  - 4s - loss: 0.5001 - acc: 0.7437 - val_loss: 0.5001 - val_acc: 0.5833
#
# Epoch 00089: val_acc did not improve
# Epoch 90/500
#  - 4s - loss: 0.5001 - acc: 0.7159 - val_loss: 0.5001 - val_acc: 0.5278
#
# Epoch 00090: val_acc did not improve
# Epoch 91/500
#  - 4s - loss: 0.5001 - acc: 0.7436 - val_loss: 0.5001 - val_acc: 0.5833
#
# Epoch 00091: val_acc did not improve
# Epoch 92/500
#  - 4s - loss: 0.5001 - acc: 0.6754 - val_loss: 0.5001 - val_acc: 0.5417
#
# Epoch 00092: val_acc did not improve
# Epoch 93/500
#  - 4s - loss: 0.5001 - acc: 0.7316 - val_loss: 0.5001 - val_acc: 0.5833
#
# Epoch 00093: val_acc did not improve
# Epoch 94/500
#  - 4s - loss: 0.5001 - acc: 0.7123 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00094: val_acc did not improve
# Epoch 95/500
#  - 4s - loss: 0.5000 - acc: 0.7223 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00095: val_acc did not improve
# Epoch 96/500
#  - 4s - loss: 0.5000 - acc: 0.7094 - val_loss: 0.5000 - val_acc: 0.5556
#
# Epoch 00096: val_acc did not improve
# Epoch 97/500
#  - 4s - loss: 0.5000 - acc: 0.7435 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00097: val_acc did not improve
# Epoch 98/500
#  - 4s - loss: 0.5000 - acc: 0.6973 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00098: val_acc did not improve
# Epoch 99/500
#  - 4s - loss: 0.5000 - acc: 0.6531 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00099: val_acc did not improve
# Epoch 100/500
#  - 4s - loss: 0.5000 - acc: 0.6653 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00100: val_acc did not improve
# Epoch 101/500
#  - 4s - loss: 0.5000 - acc: 0.7030 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00101: val_acc did not improve
# Epoch 102/500
#  - 4s - loss: 0.5000 - acc: 0.7031 - val_loss: 0.5000 - val_acc: 0.5417
#
# Epoch 00102: val_acc did not improve
# Epoch 103/500
#  - 4s - loss: 0.5000 - acc: 0.6570 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00103: val_acc did not improve
# Epoch 104/500
#  - 4s - loss: 0.5000 - acc: 0.7155 - val_loss: 0.5000 - val_acc: 0.5417
#
# Epoch 00104: val_acc did not improve
# Epoch 105/500
#  - 4s - loss: 0.5000 - acc: 0.6438 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00105: val_acc did not improve
# Epoch 106/500
#  - 4s - loss: 0.5000 - acc: 0.7184 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00106: val_acc did not improve
# Epoch 107/500
#  - 4s - loss: 0.5000 - acc: 0.7000 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00107: val_acc did not improve
# Epoch 108/500
#  - 3s - loss: 0.5000 - acc: 0.6220 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00108: val_acc did not improve
# Epoch 109/500
#  - 4s - loss: 0.5000 - acc: 0.6035 - val_loss: 0.5000 - val_acc: 0.5417
#
# Epoch 00109: val_acc did not improve
# Epoch 110/500
#  - 4s - loss: 0.5000 - acc: 0.6687 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00110: val_acc did not improve
# Epoch 111/500
#  - 4s - loss: 0.5000 - acc: 0.6872 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00111: val_acc did not improve
# Epoch 112/500
#  - 4s - loss: 0.5000 - acc: 0.6250 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00112: val_acc did not improve
# Epoch 113/500
#  - 4s - loss: 0.5000 - acc: 0.6248 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00113: val_acc did not improve
# Epoch 114/500
#  - 4s - loss: 0.5000 - acc: 0.6623 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00114: val_acc did not improve
# Epoch 115/500
#  - 3s - loss: 0.5000 - acc: 0.6592 - val_loss: 0.5000 - val_acc: 0.4583
#
# Epoch 00115: val_acc did not improve
# Epoch 116/500
#  - 3s - loss: 0.5000 - acc: 0.6126 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00116: val_acc did not improve
# Epoch 117/500
#  - 4s - loss: 0.5000 - acc: 0.6344 - val_loss: 0.5000 - val_acc: 0.4583
#
# Epoch 00117: val_acc did not improve
# Epoch 118/500
#  - 4s - loss: 0.5000 - acc: 0.6436 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00118: val_acc did not improve
# Epoch 119/500
#  - 3s - loss: 0.5000 - acc: 0.6502 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00119: val_acc did not improve
# Epoch 120/500
#  - 4s - loss: 0.5000 - acc: 0.6344 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00120: val_acc did not improve
# Epoch 121/500
#  - 4s - loss: 0.5000 - acc: 0.6222 - val_loss: 0.5000 - val_acc: 0.5139
#
# Epoch 00121: val_acc did not improve
# Epoch 122/500
#  - 4s - loss: 0.5000 - acc: 0.6060 - val_loss: 0.5000 - val_acc: 0.5278
#
# Epoch 00122: val_acc did not improve
# Epoch 123/500
#  - 3s - loss: 0.5000 - acc: 0.6160 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00123: val_acc did not improve
# Epoch 124/500
#  - 3s - loss: 0.5000 - acc: 0.6035 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00124: val_acc did not improve
# Epoch 125/500
#  - 4s - loss: 0.5000 - acc: 0.5878 - val_loss: 0.5000 - val_acc: 0.4583
#
# Epoch 00125: val_acc did not improve
# Epoch 126/500
#  - 4s - loss: 0.5000 - acc: 0.6060 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00126: val_acc did not improve
# Epoch 127/500
#  - 4s - loss: 0.5000 - acc: 0.6404 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00127: val_acc did not improve
# Epoch 128/500
#  - 4s - loss: 0.5000 - acc: 0.5941 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00128: val_acc did not improve
# Epoch 129/500
#  - 4s - loss: 0.5000 - acc: 0.5844 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00129: val_acc did not improve
# Epoch 130/500
#  - 4s - loss: 0.5000 - acc: 0.5782 - val_loss: 0.5000 - val_acc: 0.5000
#
# Epoch 00130: val_acc did not improve
# Epoch 131/500
#  - 4s - loss: 0.5000 - acc: 0.5813 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00131: val_acc did not improve
# Epoch 132/500
#  - 4s - loss: 0.5000 - acc: 0.6027 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00132: val_acc did not improve
# Epoch 133/500
#  - 4s - loss: 0.5000 - acc: 0.5748 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00133: val_acc did not improve
# Epoch 134/500
#  - 4s - loss: 0.5000 - acc: 0.5967 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00134: val_acc did not improve
# Epoch 135/500
#  - 4s - loss: 0.5000 - acc: 0.5748 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00135: val_acc did not improve
# Epoch 136/500
#  - 4s - loss: 0.5000 - acc: 0.5816 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00136: val_acc did not improve
# Epoch 137/500
#  - 4s - loss: 0.5000 - acc: 0.5938 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00137: val_acc did not improve
# Epoch 138/500
#  - 4s - loss: 0.5000 - acc: 0.5623 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00138: val_acc did not improve
# Epoch 139/500
#  - 4s - loss: 0.5000 - acc: 0.6220 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00139: val_acc did not improve
# Epoch 140/500
#  - 4s - loss: 0.5000 - acc: 0.5466 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00140: val_acc did not improve
# Epoch 141/500
#  - 4s - loss: 0.5000 - acc: 0.5566 - val_loss: 0.5000 - val_acc: 0.4583
#
# Epoch 00141: val_acc did not improve
# Epoch 142/500
#  - 4s - loss: 0.5000 - acc: 0.5685 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00142: val_acc did not improve
# Epoch 143/500
#  - 4s - loss: 0.5000 - acc: 0.5222 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00143: val_acc did not improve
# Epoch 144/500
#  - 4s - loss: 0.5000 - acc: 0.5750 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00144: val_acc did not improve
# Epoch 145/500
#  - 4s - loss: 0.5000 - acc: 0.5777 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00145: val_acc did not improve
# Epoch 146/500
#  - 4s - loss: 0.5000 - acc: 0.5466 - val_loss: 0.5000 - val_acc: 0.4583
#
# Epoch 00146: val_acc did not improve
# Epoch 147/500
#  - 4s - loss: 0.5000 - acc: 0.5409 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00147: val_acc did not improve
# Epoch 148/500
#  - 4s - loss: 0.5000 - acc: 0.5344 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00148: val_acc did not improve
# Epoch 149/500
#  - 4s - loss: 0.5000 - acc: 0.5597 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00149: val_acc did not improve
# Epoch 150/500
#  - 4s - loss: 0.5000 - acc: 0.4471 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00150: val_acc did not improve
# Epoch 151/500
#  - 4s - loss: 0.5000 - acc: 0.5378 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00151: val_acc did not improve
# Epoch 152/500
#  - 4s - loss: 0.5000 - acc: 0.4971 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00152: val_acc did not improve
# Epoch 153/500
#  - 3s - loss: 0.5000 - acc: 0.5401 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00153: val_acc did not improve
# Epoch 154/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00154: val_acc did not improve
# Epoch 155/500
#  - 4s - loss: 0.5000 - acc: 0.4974 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00155: val_acc did not improve
# Epoch 156/500
#  - 4s - loss: 0.5000 - acc: 0.4875 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00156: val_acc did not improve
# Epoch 157/500
#  - 4s - loss: 0.5000 - acc: 0.5097 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00157: val_acc did not improve
# Epoch 158/500
#  - 4s - loss: 0.5000 - acc: 0.5034 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00158: val_acc did not improve
# Epoch 159/500
#  - 3s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00159: val_acc did not improve
# Epoch 160/500
#  - 4s - loss: 0.5000 - acc: 0.5154 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00160: val_acc did not improve
# Epoch 161/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00161: val_acc did not improve
# Epoch 162/500
#  - 4s - loss: 0.5000 - acc: 0.5003 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00162: val_acc did not improve
# Epoch 163/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00163: val_acc did not improve
# Epoch 164/500
#  - 4s - loss: 0.5000 - acc: 0.5154 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00164: val_acc did not improve
# Epoch 165/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00165: val_acc did not improve
# Epoch 166/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00166: val_acc did not improve
# Epoch 167/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00167: val_acc did not improve
# Epoch 168/500
#  - 4s - loss: 0.5000 - acc: 0.5159 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00168: val_acc did not improve
# Epoch 169/500
#  - 4s - loss: 0.5000 - acc: 0.4596 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00169: val_acc did not improve
# Epoch 170/500
#  - 4s - loss: 0.5000 - acc: 0.5247 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00170: val_acc did not improve
# Epoch 171/500
#  - 4s - loss: 0.5000 - acc: 0.5003 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00171: val_acc did not improve
# Epoch 172/500
#  - 4s - loss: 0.5000 - acc: 0.4935 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00172: val_acc did not improve
# Epoch 173/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00173: val_acc did not improve
# Epoch 174/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00174: val_acc did not improve
# Epoch 175/500
#  - 4s - loss: 0.5000 - acc: 0.4937 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00175: val_acc did not improve
# Epoch 176/500
#  - 4s - loss: 0.5000 - acc: 0.4937 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00176: val_acc did not improve
# Epoch 177/500
#  - 4s - loss: 0.5000 - acc: 0.5094 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00177: val_acc did not improve
# Epoch 178/500
#  - 4s - loss: 0.5000 - acc: 0.5156 - val_loss: 0.5000 - val_acc: 0.4722
#
# Epoch 00178: val_acc did not improve
# Epoch 179/500
#  - 4s - loss: 0.5000 - acc: 0.4690 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00179: val_acc did not improve
# Epoch 180/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00180: val_acc did not improve
# Epoch 181/500
#  - 4s - loss: 0.5000 - acc: 0.5097 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00181: val_acc did not improve
# Epoch 182/500
#  - 4s - loss: 0.5000 - acc: 0.4753 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00182: val_acc did not improve
# Epoch 183/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00183: val_acc did not improve
# Epoch 184/500
#  - 4s - loss: 0.5000 - acc: 0.5065 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00184: val_acc did not improve
# Epoch 185/500
#  - 4s - loss: 0.5000 - acc: 0.4787 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00185: val_acc did not improve
# Epoch 186/500
#  - 4s - loss: 0.5000 - acc: 0.4502 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00186: val_acc did not improve
# Epoch 187/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00187: val_acc did not improve
# Epoch 188/500
#  - 4s - loss: 0.5000 - acc: 0.5094 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00188: val_acc did not improve
# Epoch 189/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00189: val_acc did not improve
# Epoch 190/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00190: val_acc did not improve
# Epoch 191/500
#  - 4s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00191: val_acc did not improve
# Epoch 192/500
#  - 4s - loss: 0.5000 - acc: 0.4974 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00192: val_acc did not improve
# Epoch 193/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00193: val_acc did not improve
# Epoch 194/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00194: val_acc did not improve
# Epoch 195/500
#  - 4s - loss: 0.5000 - acc: 0.4969 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00195: val_acc did not improve
# Epoch 196/500
#  - 4s - loss: 0.5000 - acc: 0.5031 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00196: val_acc did not improve
# Epoch 197/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00197: val_acc did not improve
# Epoch 198/500
#  - 4s - loss: 0.5000 - acc: 0.4755 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00198: val_acc did not improve
# Epoch 199/500
#  - 4s - loss: 0.5000 - acc: 0.4812 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00199: val_acc did not improve
# Epoch 200/500
#  - 3s - loss: 0.5000 - acc: 0.5031 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00200: val_acc did not improve
# Epoch 201/500
#  - 4s - loss: 0.5000 - acc: 0.5031 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00201: val_acc did not improve
# Epoch 202/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00202: val_acc did not improve
# Epoch 203/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00203: val_acc did not improve
# Epoch 204/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00204: val_acc did not improve
# Epoch 205/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00205: val_acc did not improve
# Epoch 206/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00206: val_acc did not improve
# Epoch 207/500
#  - 4s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00207: val_acc did not improve
# Epoch 208/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00208: val_acc did not improve
# Epoch 209/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00209: val_acc did not improve
# Epoch 210/500
#  - 4s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00210: val_acc did not improve
# Epoch 211/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00211: val_acc did not improve
# Epoch 212/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00212: val_acc did not improve
# Epoch 213/500
#  - 4s - loss: 0.5000 - acc: 0.5125 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00213: val_acc did not improve
# Epoch 214/500
#  - 4s - loss: 0.5000 - acc: 0.4971 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00214: val_acc did not improve
# Epoch 215/500
#  - 4s - loss: 0.5000 - acc: 0.4935 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00215: val_acc did not improve
# Epoch 216/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00216: val_acc did not improve
# Epoch 217/500
#  - 4s - loss: 0.5000 - acc: 0.4724 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00217: val_acc did not improve
# Epoch 218/500
#  - 4s - loss: 0.5000 - acc: 0.5128 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00218: val_acc did not improve
# Epoch 219/500
#  - 4s - loss: 0.5000 - acc: 0.4560 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00219: val_acc did not improve
# Epoch 220/500
#  - 4s - loss: 0.5000 - acc: 0.5034 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00220: val_acc did not improve
# Epoch 221/500
#  - 4s - loss: 0.5000 - acc: 0.4844 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00221: val_acc did not improve
# Epoch 222/500
#  - 4s - loss: 0.5000 - acc: 0.4812 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00222: val_acc did not improve
# Epoch 223/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00223: val_acc did not improve
# Epoch 224/500
#  - 4s - loss: 0.5000 - acc: 0.5125 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00224: val_acc did not improve
# Epoch 225/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00225: val_acc did not improve
# Epoch 226/500
#  - 4s - loss: 0.5000 - acc: 0.5250 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00226: val_acc did not improve
# Epoch 227/500
#  - 4s - loss: 0.5000 - acc: 0.4844 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00227: val_acc did not improve
# Epoch 228/500
#  - 3s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00228: val_acc did not improve
# Epoch 229/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00229: val_acc did not improve
# Epoch 230/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00230: val_acc did not improve
# Epoch 231/500
#  - 3s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00231: val_acc did not improve
# Epoch 232/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00232: val_acc did not improve
# Epoch 233/500
#  - 4s - loss: 0.5000 - acc: 0.4969 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00233: val_acc did not improve
# Epoch 234/500
#  - 4s - loss: 0.5000 - acc: 0.4844 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00234: val_acc did not improve
# Epoch 235/500
#  - 4s - loss: 0.5000 - acc: 0.5247 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00235: val_acc did not improve
# Epoch 236/500
#  - 3s - loss: 0.5000 - acc: 0.4628 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00236: val_acc did not improve
# Epoch 237/500
#  - 4s - loss: 0.5000 - acc: 0.5247 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00237: val_acc did not improve
# Epoch 238/500
#  - 4s - loss: 0.5000 - acc: 0.4628 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00238: val_acc did not improve
# Epoch 239/500
#  - 3s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00239: val_acc did not improve
# Epoch 240/500
#  - 4s - loss: 0.5000 - acc: 0.5216 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00240: val_acc did not improve
# Epoch 241/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00241: val_acc did not improve
# Epoch 242/500
#  - 4s - loss: 0.5000 - acc: 0.4690 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00242: val_acc did not improve
# Epoch 243/500
#  - 4s - loss: 0.5000 - acc: 0.5185 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00243: val_acc did not improve
# Epoch 244/500
#  - 3s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00244: val_acc did not improve
# Epoch 245/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00245: val_acc did not improve
# Epoch 246/500
#  - 3s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00246: val_acc did not improve
# Epoch 247/500
#  - 3s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00247: val_acc did not improve
# Epoch 248/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00248: val_acc did not improve
# Epoch 249/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00249: val_acc did not improve
# Epoch 250/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00250: val_acc did not improve
# Epoch 251/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00251: val_acc did not improve
# Epoch 252/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00252: val_acc did not improve
# Epoch 253/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00253: val_acc did not improve
# Epoch 254/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00254: val_acc did not improve
# Epoch 255/500
#  - 4s - loss: 0.5000 - acc: 0.4812 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00255: val_acc did not improve
# Epoch 256/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00256: val_acc did not improve
# Epoch 257/500
#  - 4s - loss: 0.5000 - acc: 0.5003 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00257: val_acc did not improve
# Epoch 258/500
#  - 4s - loss: 0.5000 - acc: 0.5156 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00258: val_acc did not improve
# Epoch 259/500
#  - 4s - loss: 0.5000 - acc: 0.5031 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00259: val_acc did not improve
# Epoch 260/500
#  - 4s - loss: 0.5000 - acc: 0.4653 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00260: val_acc did not improve
# Epoch 261/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00261: val_acc did not improve
# Epoch 262/500
#  - 4s - loss: 0.5000 - acc: 0.5188 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00262: val_acc did not improve
# Epoch 263/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00263: val_acc did not improve
# Epoch 264/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00264: val_acc did not improve
# Epoch 265/500
#  - 4s - loss: 0.5000 - acc: 0.5006 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00265: val_acc did not improve
# Epoch 266/500
#  - 4s - loss: 0.5000 - acc: 0.4252 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00266: val_acc did not improve
# Epoch 267/500
#  - 4s - loss: 0.5000 - acc: 0.5440 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00267: val_acc did not improve
# Epoch 268/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00268: val_acc did not improve
# Epoch 269/500
#  - 4s - loss: 0.5000 - acc: 0.5000 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00269: val_acc did not improve
# Epoch 270/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00270: val_acc did not improve
# Epoch 271/500
#  - 4s - loss: 0.5000 - acc: 0.5034 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00271: val_acc did not improve
# Epoch 272/500
#  - 4s - loss: 0.5000 - acc: 0.4565 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00272: val_acc did not improve
# Epoch 273/500
#  - 4s - loss: 0.5000 - acc: 0.5097 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00273: val_acc did not improve
# Epoch 274/500
#  - 4s - loss: 0.5000 - acc: 0.4685 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00274: val_acc did not improve
# Epoch 275/500
#  - 4s - loss: 0.5000 - acc: 0.4812 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00275: val_acc did not improve
# Epoch 276/500
#  - 4s - loss: 0.5000 - acc: 0.5469 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00276: val_acc did not improve
# Epoch 277/500
#  - 3s - loss: 0.5000 - acc: 0.4442 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00277: val_acc did not improve
# Epoch 278/500
#  - 4s - loss: 0.5000 - acc: 0.5219 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00278: val_acc did not improve
# Epoch 279/500
#  - 3s - loss: 0.5000 - acc: 0.4659 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00279: val_acc did not improve
# Epoch 280/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00280: val_acc did not improve
# Epoch 281/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00281: val_acc did not improve
# Epoch 282/500
#  - 4s - loss: 0.5000 - acc: 0.5156 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00282: val_acc did not improve
# Epoch 283/500
#  - 3s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00283: val_acc did not improve
# Epoch 284/500
#  - 4s - loss: 0.5000 - acc: 0.4628 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00284: val_acc did not improve
# Epoch 285/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00285: val_acc did not improve
# Epoch 286/500
#  - 4s - loss: 0.5000 - acc: 0.5154 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00286: val_acc did not improve
# Epoch 287/500
#  - 3s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00287: val_acc did not improve
# Epoch 288/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00288: val_acc did not improve
# Epoch 289/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00289: val_acc did not improve
# Epoch 290/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00290: val_acc did not improve
# Epoch 291/500
#  - 4s - loss: 0.5000 - acc: 0.5247 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00291: val_acc did not improve
# Epoch 292/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00292: val_acc did not improve
# Epoch 293/500
#  - 4s - loss: 0.5000 - acc: 0.4753 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00293: val_acc did not improve
# Epoch 294/500
#  - 4s - loss: 0.5000 - acc: 0.5003 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00294: val_acc did not improve
# Epoch 295/500
#  - 4s - loss: 0.5000 - acc: 0.4628 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00295: val_acc did not improve
# Epoch 296/500
#  - 4s - loss: 0.5000 - acc: 0.5216 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00296: val_acc did not improve
# Epoch 297/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00297: val_acc did not improve
# Epoch 298/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00298: val_acc did not improve
# Epoch 299/500
#  - 4s - loss: 0.5000 - acc: 0.5216 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00299: val_acc did not improve
# Epoch 300/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00300: val_acc did not improve
# Epoch 301/500
#  - 4s - loss: 0.5000 - acc: 0.4841 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00301: val_acc did not improve
# Epoch 302/500
#  - 4s - loss: 0.5000 - acc: 0.5125 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00302: val_acc did not improve
# Epoch 303/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00303: val_acc did not improve
# Epoch 304/500
#  - 4s - loss: 0.5000 - acc: 0.4659 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00304: val_acc did not improve
# Epoch 305/500
#  - 4s - loss: 0.5000 - acc: 0.5097 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00305: val_acc did not improve
# Epoch 306/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00306: val_acc did not improve
# Epoch 307/500
#  - 4s - loss: 0.5000 - acc: 0.4935 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00307: val_acc did not improve
# Epoch 308/500
#  - 4s - loss: 0.5000 - acc: 0.4963 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00308: val_acc did not improve
# Epoch 309/500
#  - 4s - loss: 0.5000 - acc: 0.5159 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00309: val_acc did not improve
# Epoch 310/500
#  - 4s - loss: 0.5000 - acc: 0.5310 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00310: val_acc did not improve
# Epoch 311/500
#  - 3s - loss: 0.5000 - acc: 0.4377 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00311: val_acc did not improve
# Epoch 312/500
#  - 4s - loss: 0.5000 - acc: 0.5094 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00312: val_acc did not improve
# Epoch 313/500
#  - 3s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00313: val_acc did not improve
# Epoch 314/500
#  - 4s - loss: 0.5000 - acc: 0.4971 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00314: val_acc did not improve
# Epoch 315/500
#  - 4s - loss: 0.5000 - acc: 0.4659 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00315: val_acc did not improve
# Epoch 316/500
#  - 3s - loss: 0.5000 - acc: 0.4661 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00316: val_acc did not improve
# Epoch 317/500
#  - 4s - loss: 0.5000 - acc: 0.5000 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00317: val_acc did not improve
# Epoch 318/500
#  - 3s - loss: 0.5000 - acc: 0.5154 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00318: val_acc did not improve
# Epoch 319/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00319: val_acc did not improve
# Epoch 320/500
#  - 3s - loss: 0.5000 - acc: 0.5003 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00320: val_acc did not improve
# Epoch 321/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00321: val_acc did not improve
# Epoch 322/500
#  - 4s - loss: 0.5000 - acc: 0.4753 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00322: val_acc did not improve
# Epoch 323/500
#  - 4s - loss: 0.5000 - acc: 0.4753 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00323: val_acc did not improve
# Epoch 324/500
#  - 4s - loss: 0.5000 - acc: 0.5279 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00324: val_acc did not improve
# Epoch 325/500
#  - 4s - loss: 0.5000 - acc: 0.4596 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00325: val_acc did not improve
# Epoch 326/500
#  - 4s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00326: val_acc did not improve
# Epoch 327/500
#  - 4s - loss: 0.5000 - acc: 0.4971 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00327: val_acc did not improve
# Epoch 328/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00328: val_acc did not improve
# Epoch 329/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00329: val_acc did not improve
# Epoch 330/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00330: val_acc did not improve
# Epoch 331/500
#  - 4s - loss: 0.5000 - acc: 0.5154 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00331: val_acc did not improve
# Epoch 332/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00332: val_acc did not improve
# Epoch 333/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00333: val_acc did not improve
# Epoch 334/500
#  - 4s - loss: 0.5000 - acc: 0.5065 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00334: val_acc did not improve
# Epoch 335/500
#  - 4s - loss: 0.5000 - acc: 0.4903 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00335: val_acc did not improve
# Epoch 336/500
#  - 4s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00336: val_acc did not improve
# Epoch 337/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00337: val_acc did not improve
# Epoch 338/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00338: val_acc did not improve
# Epoch 339/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00339: val_acc did not improve
# Epoch 340/500
#  - 4s - loss: 0.5000 - acc: 0.5375 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00340: val_acc did not improve
# Epoch 341/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00341: val_acc did not improve
# Epoch 342/500
#  - 4s - loss: 0.5000 - acc: 0.4596 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00342: val_acc did not improve
# Epoch 343/500
#  - 4s - loss: 0.5000 - acc: 0.5182 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00343: val_acc did not improve
# Epoch 344/500
#  - 4s - loss: 0.5000 - acc: 0.4971 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00344: val_acc did not improve
# Epoch 345/500
#  - 4s - loss: 0.5000 - acc: 0.4841 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00345: val_acc did not improve
# Epoch 346/500
#  - 4s - loss: 0.5000 - acc: 0.5190 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00346: val_acc did not improve
# Epoch 347/500
#  - 4s - loss: 0.5000 - acc: 0.4531 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00347: val_acc did not improve
# Epoch 348/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00348: val_acc did not improve
# Epoch 349/500
#  - 4s - loss: 0.5000 - acc: 0.5094 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00349: val_acc did not improve
# Epoch 350/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00350: val_acc did not improve
# Epoch 351/500
#  - 4s - loss: 0.5000 - acc: 0.4781 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00351: val_acc did not improve
# Epoch 352/500
#  - 3s - loss: 0.5000 - acc: 0.4849 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00352: val_acc did not improve
# Epoch 353/500
#  - 4s - loss: 0.5000 - acc: 0.5063 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00353: val_acc did not improve
# Epoch 354/500
#  - 4s - loss: 0.5000 - acc: 0.5000 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00354: val_acc did not improve
# Epoch 355/500
#  - 4s - loss: 0.5000 - acc: 0.4690 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00355: val_acc did not improve
# Epoch 356/500
#  - 4s - loss: 0.5000 - acc: 0.5031 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00356: val_acc did not improve
# Epoch 357/500
#  - 4s - loss: 0.5000 - acc: 0.5120 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00357: val_acc did not improve
# Epoch 358/500
#  - 4s - loss: 0.5000 - acc: 0.4969 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00358: val_acc did not improve
# Epoch 359/500
#  - 3s - loss: 0.5000 - acc: 0.4755 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00359: val_acc did not improve
# Epoch 360/500
#  - 4s - loss: 0.5000 - acc: 0.4969 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00360: val_acc did not improve
# Epoch 361/500
#  - 3s - loss: 0.5000 - acc: 0.4721 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00361: val_acc did not improve
# Epoch 362/500
#  - 4s - loss: 0.5000 - acc: 0.5310 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00362: val_acc did not improve
# Epoch 363/500
#  - 4s - loss: 0.5000 - acc: 0.4690 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00363: val_acc did not improve
# Epoch 364/500
#  - 4s - loss: 0.5000 - acc: 0.5094 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00364: val_acc did not improve
# Epoch 365/500
#  - 4s - loss: 0.5000 - acc: 0.4875 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00365: val_acc did not improve
# Epoch 366/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00366: val_acc did not improve
# Epoch 367/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00367: val_acc did not improve
# Epoch 368/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00368: val_acc did not improve
# Epoch 369/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00369: val_acc did not improve
# Epoch 370/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00370: val_acc did not improve
# Epoch 371/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00371: val_acc did not improve
# Epoch 372/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00372: val_acc did not improve
# Epoch 373/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00373: val_acc did not improve
# Epoch 374/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00374: val_acc did not improve
# Epoch 375/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00375: val_acc did not improve
# Epoch 376/500
#  - 4s - loss: 0.5000 - acc: 0.4937 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00376: val_acc did not improve
# Epoch 377/500
#  - 4s - loss: 0.5000 - acc: 0.4755 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00377: val_acc did not improve
# Epoch 378/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00378: val_acc did not improve
# Epoch 379/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00379: val_acc did not improve
# Epoch 380/500
#  - 4s - loss: 0.5000 - acc: 0.5247 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00380: val_acc did not improve
# Epoch 381/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00381: val_acc did not improve
# Epoch 382/500
#  - 4s - loss: 0.5000 - acc: 0.4753 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00382: val_acc did not improve
# Epoch 383/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00383: val_acc did not improve
# Epoch 384/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00384: val_acc did not improve
# Epoch 385/500
#  - 4s - loss: 0.5000 - acc: 0.4909 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00385: val_acc did not improve
# Epoch 386/500
#  - 4s - loss: 0.5000 - acc: 0.5128 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00386: val_acc did not improve
# Epoch 387/500
#  - 4s - loss: 0.5000 - acc: 0.4750 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00387: val_acc did not improve
# Epoch 388/500
#  - 4s - loss: 0.5000 - acc: 0.4875 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00388: val_acc did not improve
# Epoch 389/500
#  - 4s - loss: 0.5000 - acc: 0.5097 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00389: val_acc did not improve
# Epoch 390/500
#  - 4s - loss: 0.5000 - acc: 0.4781 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00390: val_acc did not improve
# Epoch 391/500
#  - 3s - loss: 0.5000 - acc: 0.4812 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00391: val_acc did not improve
# Epoch 392/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00392: val_acc did not improve
# Epoch 393/500
#  - 4s - loss: 0.5000 - acc: 0.5216 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00393: val_acc did not improve
# Epoch 394/500
#  - 4s - loss: 0.5000 - acc: 0.5094 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00394: val_acc did not improve
# Epoch 395/500
#  - 4s - loss: 0.5000 - acc: 0.4810 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00395: val_acc did not improve
# Epoch 396/500
#  - 4s - loss: 0.5000 - acc: 0.5279 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00396: val_acc did not improve
# Epoch 397/500
#  - 4s - loss: 0.5000 - acc: 0.4685 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00397: val_acc did not improve
# Epoch 398/500
#  - 4s - loss: 0.5000 - acc: 0.5185 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00398: val_acc did not improve
# Epoch 399/500
#  - 3s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00399: val_acc did not improve
# Epoch 400/500
#  - 4s - loss: 0.5000 - acc: 0.5182 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00400: val_acc did not improve
# Epoch 401/500
#  - 4s - loss: 0.5000 - acc: 0.5219 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00401: val_acc did not improve
# Epoch 402/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00402: val_acc did not improve
# Epoch 403/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00403: val_acc did not improve
# Epoch 404/500
#  - 4s - loss: 0.5000 - acc: 0.5279 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00404: val_acc did not improve
# Epoch 405/500
#  - 4s - loss: 0.5000 - acc: 0.4935 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00405: val_acc did not improve
# Epoch 406/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00406: val_acc did not improve
# Epoch 407/500
#  - 3s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00407: val_acc did not improve
# Epoch 408/500
#  - 4s - loss: 0.5000 - acc: 0.4903 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00408: val_acc did not improve
# Epoch 409/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00409: val_acc did not improve
# Epoch 410/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00410: val_acc did not improve
# Epoch 411/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00411: val_acc did not improve
# Epoch 412/500
#  - 4s - loss: 0.5000 - acc: 0.4753 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00412: val_acc did not improve
# Epoch 413/500
#  - 4s - loss: 0.5000 - acc: 0.5216 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00413: val_acc did not improve
# Epoch 414/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00414: val_acc did not improve
# Epoch 415/500
#  - 4s - loss: 0.5000 - acc: 0.4937 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00415: val_acc did not improve
# Epoch 416/500
#  - 4s - loss: 0.5000 - acc: 0.4963 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00416: val_acc did not improve
# Epoch 417/500
#  - 4s - loss: 0.5000 - acc: 0.5063 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00417: val_acc did not improve
# Epoch 418/500
#  - 4s - loss: 0.5000 - acc: 0.5156 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00418: val_acc did not improve
# Epoch 419/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00419: val_acc did not improve
# Epoch 420/500
#  - 4s - loss: 0.5000 - acc: 0.4750 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00420: val_acc did not improve
# Epoch 421/500
#  - 4s - loss: 0.5000 - acc: 0.5125 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00421: val_acc did not improve
# Epoch 422/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00422: val_acc did not improve
# Epoch 423/500
#  - 4s - loss: 0.5000 - acc: 0.5154 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00423: val_acc did not improve
# Epoch 424/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00424: val_acc did not improve
# Epoch 425/500
#  - 4s - loss: 0.5000 - acc: 0.5000 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00425: val_acc did not improve
# Epoch 426/500
#  - 4s - loss: 0.5000 - acc: 0.5182 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00426: val_acc did not improve
# Epoch 427/500
#  - 4s - loss: 0.5000 - acc: 0.4781 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00427: val_acc did not improve
# Epoch 428/500
#  - 4s - loss: 0.5000 - acc: 0.5000 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00428: val_acc did not improve
# Epoch 429/500
#  - 4s - loss: 0.5000 - acc: 0.5063 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00429: val_acc did not improve
# Epoch 430/500
#  - 3s - loss: 0.5000 - acc: 0.4838 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00430: val_acc did not improve
# Epoch 431/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00431: val_acc did not improve
# Epoch 432/500
#  - 4s - loss: 0.5000 - acc: 0.4878 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00432: val_acc did not improve
# Epoch 433/500
#  - 4s - loss: 0.5000 - acc: 0.5623 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00433: val_acc did not improve
# Epoch 434/500
#  - 4s - loss: 0.5000 - acc: 0.4594 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00434: val_acc did not improve
# Epoch 435/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00435: val_acc did not improve
# Epoch 436/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00436: val_acc did not improve
# Epoch 437/500
#  - 4s - loss: 0.5000 - acc: 0.5213 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00437: val_acc did not improve
# Epoch 438/500
#  - 4s - loss: 0.5000 - acc: 0.5000 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00438: val_acc did not improve
# Epoch 439/500
#  - 4s - loss: 0.5000 - acc: 0.5120 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00439: val_acc did not improve
# Epoch 440/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00440: val_acc did not improve
# Epoch 441/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00441: val_acc did not improve
# Epoch 442/500
#  - 4s - loss: 0.5000 - acc: 0.5031 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00442: val_acc did not improve
# Epoch 443/500
#  - 3s - loss: 0.5000 - acc: 0.5097 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00443: val_acc did not improve
# Epoch 444/500
#  - 3s - loss: 0.5000 - acc: 0.4255 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00444: val_acc did not improve
# Epoch 445/500
#  - 4s - loss: 0.5000 - acc: 0.4937 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00445: val_acc did not improve
# Epoch 446/500
#  - 4s - loss: 0.5000 - acc: 0.5125 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00446: val_acc did not improve
# Epoch 447/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00447: val_acc did not improve
# Epoch 448/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00448: val_acc did not improve
# Epoch 449/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00449: val_acc did not improve
# Epoch 450/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00450: val_acc did not improve
# Epoch 451/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00451: val_acc did not improve
# Epoch 452/500
#  - 4s - loss: 0.5000 - acc: 0.4815 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00452: val_acc did not improve
# Epoch 453/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00453: val_acc did not improve
# Epoch 454/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00454: val_acc did not improve
# Epoch 455/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00455: val_acc did not improve
# Epoch 456/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00456: val_acc did not improve
# Epoch 457/500
#  - 4s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00457: val_acc did not improve
# Epoch 458/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00458: val_acc did not improve
# Epoch 459/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00459: val_acc did not improve
# Epoch 460/500
#  - 4s - loss: 0.5000 - acc: 0.4875 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00460: val_acc did not improve
# Epoch 461/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00461: val_acc did not improve
# Epoch 462/500
#  - 4s - loss: 0.5000 - acc: 0.5310 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00462: val_acc did not improve
# Epoch 463/500
#  - 4s - loss: 0.5000 - acc: 0.4997 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00463: val_acc did not improve
# Epoch 464/500
#  - 4s - loss: 0.5000 - acc: 0.4846 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00464: val_acc did not improve
# Epoch 465/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00465: val_acc did not improve
# Epoch 466/500
#  - 4s - loss: 0.5000 - acc: 0.5057 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00466: val_acc did not improve
# Epoch 467/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00467: val_acc did not improve
# Epoch 468/500
#  - 4s - loss: 0.5000 - acc: 0.5341 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00468: val_acc did not improve
# Epoch 469/500
#  - 4s - loss: 0.5000 - acc: 0.4716 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00469: val_acc did not improve
# Epoch 470/500
#  - 4s - loss: 0.5000 - acc: 0.5279 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00470: val_acc did not improve
# Epoch 471/500
#  - 4s - loss: 0.5000 - acc: 0.4841 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00471: val_acc did not improve
# Epoch 472/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00472: val_acc did not improve
# Epoch 473/500
#  - 4s - loss: 0.5000 - acc: 0.4750 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00473: val_acc did not improve
# Epoch 474/500
#  - 3s - loss: 0.5000 - acc: 0.5339 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00474: val_acc did not improve
# Epoch 475/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00475: val_acc did not improve
# Epoch 476/500
#  - 4s - loss: 0.5000 - acc: 0.4661 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00476: val_acc did not improve
# Epoch 477/500
#  - 4s - loss: 0.5000 - acc: 0.5250 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00477: val_acc did not improve
# Epoch 478/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00478: val_acc did not improve
# Epoch 479/500
#  - 4s - loss: 0.5000 - acc: 0.4935 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00479: val_acc did not improve
# Epoch 480/500
#  - 4s - loss: 0.5000 - acc: 0.4903 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00480: val_acc did not improve
# Epoch 481/500
#  - 4s - loss: 0.5000 - acc: 0.4912 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00481: val_acc did not improve
# Epoch 482/500
#  - 4s - loss: 0.5000 - acc: 0.4844 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00482: val_acc did not improve
# Epoch 483/500
#  - 4s - loss: 0.5000 - acc: 0.5128 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00483: val_acc did not improve
# Epoch 484/500
#  - 4s - loss: 0.5000 - acc: 0.4778 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00484: val_acc did not improve
# Epoch 485/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00485: val_acc did not improve
# Epoch 486/500
#  - 4s - loss: 0.5000 - acc: 0.4872 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00486: val_acc did not improve
# Epoch 487/500
#  - 4s - loss: 0.5000 - acc: 0.5341 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00487: val_acc did not improve
# Epoch 488/500
#  - 4s - loss: 0.5000 - acc: 0.4935 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00488: val_acc did not improve
# Epoch 489/500
#  - 4s - loss: 0.5000 - acc: 0.4940 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00489: val_acc did not improve
# Epoch 490/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00490: val_acc did not improve
# Epoch 491/500
#  - 3s - loss: 0.5000 - acc: 0.4784 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00491: val_acc did not improve
# Epoch 492/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00492: val_acc did not improve
# Epoch 493/500
#  - 4s - loss: 0.5000 - acc: 0.5091 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00493: val_acc did not improve
# Epoch 494/500
#  - 4s - loss: 0.5000 - acc: 0.4966 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00494: val_acc did not improve
# Epoch 495/500
#  - 4s - loss: 0.5000 - acc: 0.5060 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00495: val_acc did not improve
# Epoch 496/500
#  - 4s - loss: 0.5000 - acc: 0.4971 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00496: val_acc did not improve
# Epoch 497/500
#  - 4s - loss: 0.5000 - acc: 0.5029 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00497: val_acc did not improve
# Epoch 498/500
#  - 4s - loss: 0.5000 - acc: 0.4721 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00498: val_acc did not improve
# Epoch 499/500
#  - 4s - loss: 0.5000 - acc: 0.5122 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00499: val_acc did not improve
# Epoch 500/500
#  - 4s - loss: 0.5000 - acc: 0.4906 - val_loss: 0.5000 - val_acc: 0.4861
#
# Epoch 00500: val_acc did not improve

# %%
# plot history 
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc= 'upper left' )
plt.show()
# Out:
# dict_keys(['val_loss', 'acc', 'val_acc', 'loss'])
